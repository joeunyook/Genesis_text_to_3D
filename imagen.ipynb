# %%
# !pip install --upgrade --user google-cloud-aiplatform
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 108.2 MB/s eta 0:00:00
# ...
#   WARNING: The script tb-gcp-uploader is installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import vertexai
vertexai.init(project="tmi-reddit-content-moderation", location="us-west4")

# %%
from vertexai.preview.vision_models import ImageGenerationModel
from PIL import Image as PIL_Image
from PIL import ImageOps as PIL_ImageOps
import typing
import IPython.display

def display_image(image, max_width: int = 600, max_height: int = 350):
    pil_image = typing.cast(PIL_Image.Image, image._pil_image)
    if pil_image.mode != "RGB":
        pil_image = pil_image.convert("RGB")
    image_width, image_height = pil_image.size
    if max_width < image_width or max_height < image_height:
        pil_image = PIL_ImageOps.contain(pil_image, (max_width, max_height))
    IPython.display.display(pil_image)

# Get user input
prompt = input("Enter your prompt: ")

# Generate image
generation_model = ImageGenerationModel.from_pretrained("imagen-3.0-generate-002")
images = generation_model.generate_images(
    prompt=prompt,
    number_of_images=1,
    aspect_ratio="1:1",
    add_watermark=True,
)

# Display
display_image(images[0])
# Out:
# Enter your prompt:  genius hacker
# <PIL.Image.Image image mode=RGB size=350x350>

# %%
image_path = "TripoSR/examples/generated.png"
images[0]._pil_image.save("TripoSR/examples/generated.png")

# %%
from IPython.display import Image, display
from pathlib import Path
import os

# Define the image path
image_path = Path("TripoSR/examples/generated.png")

# Check if it exists
if image_path.exists():
    print("✅ Found generated image.")
    print("📅 Last modified:", image_path.stat().st_mtime)
    display(Image(filename=str(image_path)))
else:
    print("❌ Image not found at:", image_path.resolve())
# Out:
# ✅ Found generated image.
# 📅 Last modified: 1742699281.9594462

# %%
# !python TripoSR/run.py TripoSR/examples/generated.png --output-dir TripoSR/output
# Out:
# 2025-03-23 03:08:09,333 - INFO - Initializing model ...
# /opt/conda/lib/python3.10/site-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /opt/conda/lib/python3.10/site-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2025-03-23 03:08:15,535 - INFO - Initializing model finished in 6201.68ms.
# 2025-03-23 03:08:15,535 - INFO - Processing images ...
# 2025-03-23 03:08:17,153 - INFO - Processing images finished in 1617.40ms.
# 2025-03-23 03:08:17,153 - INFO - Running image 1/1 ...
# 2025-03-23 03:08:17,153 - INFO - Running model ...
# 2025-03-23 03:08:18,854 - INFO - Running model finished in 1701.02ms.
# ...
